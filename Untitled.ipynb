# %%
import pandas as pd
import math
import numpy as np

# %%
def prod_cost_clean(df):
    for x, y in zip(df.prod_cost, df.index):
        x = float(x)
        rep = math.isnan(float(df.prod_cost[y]))
        print(rep)
        if rep == True or x == 0.0 or x < 0.0:
            df['prod_cost'][y] = df[['prod_cost']].mean()            
    return df

# %%
df = pd.read_csv("mower_market_snapshot.csv", sep=';')

# %%
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
#Décrire le dataset : max, min, moyenne, quartiles, nombre de valeurs par colonne,
#Afficher les variables uniques pour Product type, quality, warranty
#Comprendre le problème + Faire des recherches sur le RMLSE

# %%
df['prod_cost'] =  df['prod_cost'].replace('unknown', np.nan)

# %%
prod_cost_clean(df)
# Out:
# 195.03551928211797
# 0
# False
# 151.31809934886763
# 1
# False
# 178.13731921134948
# 2
# False
# 162.82946157588628
# 3
# False
# 141.48693796090603
# 4
# False
# 177.01288573033196
# 5
# False
# 173.26373572791334
# 6
# False
# 184.56014118975136
# 7
# False
# 170.14746134881673
# 8
# False
# 186.1262903279073
# 9
# False
# 148.41503918168814
# 10
# False
# 195.81946333014687
# 11
# False
# 170.99957332823436
# 12
# False
# 139.9698450224172
# 13
# False
# 164.85980921486097
# 14
# False
# 208.75289206129202
# 15
# False
# 167.18992276086493
# 16
# False
# 161.26365131854845
# 17
# False
# 184.97391331970988
# 18
# False
# 156.25068438864682
# 19
# False
# 158.91492725312412
# 20
# False
# 185.56823156025672
# 21
# False
# 184.94371512383591
# 22
# False
# 199.8793048937394
# 23
# False
# 161.1003672316781
# 24
# False
# 149.78979724770687
# 25
# False
# 144.6246131371376
# 26
# False
# 148.98982075813146
# 27
# False
# 167.1419253018245
# 28
# False
# 183.50646371242973
# 29
# ...

# %%
df['warranty_clean'] = df['warranty'].astype(str).str[0]
df = df.drop('warranty', axis=1)

# %%
import numpy as np
# Out:
#                prod_cost
# 0     195.03551928211797
# 1     151.31809934886763
# 2     178.13731921134948
# 3     162.82946157588628
# 4     141.48693796090603
# ...                  ...
# 1394  11.498540481074583
# 1395  11.380588736668567
# 1396                 NaN
# 1397   9.794196773761458
# 1398  10.696216086742934
#
# [1399 rows x 1 columns]

# %%
0  195

# %%
- Remplacer les NaN par la médiane
- Remplacer les NaN par la moyenne 
- Supprimer les lignes
