# %%
import pandas as pd

# %%
df = pd.read_csv("mower_market_snapshot.csv", sep=';')

# %%
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
#Décrire le dataset: max, min, moyenne, quartiles, nombre de valeurs par colonne
#afficher les variables uniques pour Product type, quality, warranty
#Comprendre le problème + faire des recherches sur le RMLSE

# %%
df.describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
df.count()
# Out:
# capacity          1399
# failure_rate      1399
# id                1399
# margin            1399
# price             1399
# prod_cost         1381
# product_type      1399
# quality           1399
# warranty          1399
# market_share      1399
# attractiveness    1399
# dtype: int64

# %%
import numpy as np

# %%
df.min()
# Out:
# capacity            0.0138838
# failure_rate        0.0289062
# id                      18259
# margin                 52.944
# price                 62.1622
# product_type      auto-portee
# quality                 Hight
# warranty                 1 an
# market_share      0.000563646
# attractiveness       0.297384
# dtype: object

# %%
df.max()
# Out:
# capacity             104.615
# failure_rate        0.302465
# id                     19657
# margin               790.013
# price                964.974
# product_type         essence
# quality               Medium
# warranty               3anss
# market_share      0.00931431
# attractiveness      0.952877
# dtype: object

# %%
df.mean()
# Out:
# capacity             47.663266
# failure_rate          0.166448
# id                18958.000000
# margin              186.262609
# price               260.075165
# market_share          0.002144
# attractiveness        0.636507
# dtype: float64

# %%
df.quantile([0.25, 0.5, 0.75])
# Out:
#        capacity  failure_rate       id      margin       price  market_share  \
# 0.25  35.853890      0.095678  18608.5   62.247602   73.379425      0.001135
# 0.50  50.309242      0.199796  18958.0   66.299672   78.439753      0.001399
# 0.75  61.905015      0.228011  19307.5  265.370973  384.265263      0.002446
#
#       attractiveness
# 0.25        0.549369
# 0.50        0.641351
# 0.75        0.726746

# %%
df.warranty.unique()
# Out:
# array(['3ans', '3 ans.', '3_ans', '3 anss', '3ans.', '3 ans', '3_ans.',
#        '3_anss', '3anss', '2 ans', '2 anss', '2anss', '2_ans', '2ans',
#        '2_ans.', '2 ans.', '2_anss', '2ans.', '1 an', '1an', '1_an.',
#        '1ans', '1an.', '1_ans', '1_an', '1 an.', '1 ans'], dtype=object)

# %%
df.quality.unique()
# Out:
# array(['Low', 'Medium', 'Hight'], dtype=object)

# %%
df.product_type.unique()
# Out:
# array(['auto-portee', 'electrique', 'essence'], dtype=object)

# %%
df['garantie'] = df['warranty'].astype(str).str[0]
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df = df.drop('warranty', axis=1)

# %%
df.isnull()
# Out:
#       capacity  failure_rate     id  margin  price  prod_cost  product_type  \
# 0        False         False  False   False  False      False         False
# 1        False         False  False   False  False      False         False
# 2        False         False  False   False  False      False         False
# 3        False         False  False   False  False      False         False
# 4        False         False  False   False  False      False         False
# ...        ...           ...    ...     ...    ...        ...           ...
# 1394     False         False  False   False  False      False         False
# 1395     False         False  False   False  False      False         False
# 1396     False         False  False   False  False      False         False
# 1397     False         False  False   False  False      False         False
# 1398     False         False  False   False  False      False         False
#
#       quality  market_share  attractiveness  garantie
# ...

# %%
bool_series = pd.isnull(df["prod_cost"])

# %%
df[bool_series]
# Out:
#        capacity  failure_rate     id      margin       price prod_cost  \
# 107   31.019904      0.038149  19522  658.116184  411.087712       NaN
# 135   23.340049      0.039023  19596  726.196516  396.773981       NaN
# 170   34.857361      0.114097  18964  241.552664   72.970497       NaN
# 232   41.875278      0.096177  18736  291.932051  891.665482       NaN
# 280   33.383391      0.091738  18359  260.868096  869.049664       NaN
# 331   35.137522      0.093361  19251  262.668491   77.213051       NaN
# 471   44.813757      0.102862  18379  259.776821   72.035083       NaN
# 607   62.926054      0.228961  18806   66.590674  843.474741       NaN
# 711   50.760451      0.275969  19381   60.069105  401.325676       NaN
# 732   39.691240      0.227008  18535   61.127369  389.408396       NaN
# 795   59.270658      0.201919  19399   60.991972  397.807476       NaN
# 804   44.467231      0.191641  19038   65.094740  861.597824       NaN
# ...

# %%
df.loc[:, 'quality']
# Out:
# 0          Low
# 1          Low
# 2          Low
# 3          Low
# 4       Medium
#          ...
# 1394    Medium
# 1395       Low
# 1396       Low
# 1397       Low
# 1398       Low
# Name: quality, Length: 1399, dtype: object

# %%
df[df.quality=='Low']
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 7      8.676314      0.042066  18943  633.515449  818.075591
# ...         ...           ...    ...         ...         ...
# 1393  40.831294      0.217289  18950   62.296416   69.391858
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality  market_share  attractiveness  \
# 0     195.03551928211797  auto-portee     Low      0.006360        0.650648
# 1     151.31809934886763  auto-portee     Low      0.006840        0.699792
# ...

# %%
df[df.quality=='Low'].prod_cost
# Out:
# 0       195.03551928211797
# 1       151.31809934886763
# 2       178.13731921134948
# 3       162.82946157588628
# 7       184.56014118975136
#                ...
# 1393     7.095442545963653
# 1395    11.380588736668567
# 1396               unknown
# 1397     9.794196773761458
# 1398    10.696216086742934
# Name: prod_cost, Length: 971, dtype: object

# %%
lowquality = df[df.quality=='Low'].prod_cost

# %%
lowquality
# Out:
# 0       195.03551928211797
# 1       151.31809934886763
# 2       178.13731921134948
# 3       162.82946157588628
# 7       184.56014118975136
#                ...
# 1393     7.095442545963653
# 1395    11.380588736668567
# 1396               unknown
# 1397     9.794196773761458
# 1398    10.696216086742934
# Name: prod_cost, Length: 971, dtype: object

# %%
df['lowquality'] = lowquality
df.head()
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
# 3  27.220131      0.041303  18728  654.255635  817.085097  162.82946157588628
# 4  16.370911      0.037938  18722  703.094527  844.581465  141.48693796090603
#
#   product_type quality  market_share  attractiveness garantie  \
# 0  auto-portee     Low      0.006360        0.650648        3
# 1  auto-portee     Low      0.006840        0.699792        3
# 2  auto-portee     Low      0.006179        0.632129        3
# 3  auto-portee     Low      0.007925        0.810730        3
# 4  auto-portee  Medium      0.007406        0.757614        3
#
#            lowquality
# 0  195.03551928211797
# 1  151.31809934886763
# 2  178.13731921134948
# 3  162.82946157588628
# ...

# %%
df.lowquality.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     550     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 551     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     552
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#
# ...

# %%
np.nanmean.lowquality()
